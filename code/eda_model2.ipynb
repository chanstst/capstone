# %% [markdown]
# # UK Property Image Classification
# ### EDA model 2
#
# ---

# %% [markdown]
# #### Data:
# Loading more images (150 each class, from 100) to build a second model
#
# #### Model:
# Convoluted Neural Nets
#
# #### Initial model results:
# The model validation accuracy is 80%, compared to a base case of 50%. 200 images are used in the initial model training
#
# #### Training model with more images:
# Validation accuracy score is 78%, similar to that of a smaller set of images. Satisfactory results given that there is more confusion with more interior images

# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os
from math import ceil
from PIL import Image

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder

from skimage import io
from skimage import color
from skimage.transform import rescale, resize, downscale_local_mean

import pickle

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D

# %%
# For reproducibility
np.random.seed(42)

# %%
# function to load folder into arrays and  then it returns that same array

def load_files(path):
    # Put files into lists and return them as one list of size 4
    image_files = os.listdir(path)
    image_files = [path + x for x in image_files]
    return image_files

# %%
# feeding images into numpy ndarray

def load_array(image_files, min_size):
    X = np.array([])
    for file in image_files:
        try:
            img = io.imread(file)
            img_resized = resize(img, (min_size,min_size), anti_aliasing=True)
            if X.shape[0] == 0:
                X = np.array([img_resized])
            else:
                X = np.append(X, [img_resized], axis = 0)
        
        except:
            print("image error: ", file)
    return X

# %% [markdown]
# #### Load the training data - old buildings

# %%
# Photos of old or period buildings

image_path = "../images/old_samples/"
image_files = load_files(image_path)

# second batch of old buildings - 150 images of interior
image_path2 = "../images/old_interior/"
image_files2 = load_files(image_path2)

# concatenating 2 lists
image_files = image_files + image_files2

# set min_size = 400
min_size = 400

print(f"number of image_files = {len(image_files)}")
print(f"min_size = {min_size}")
# Out:
# number of image_files = 250
# min_size = 400

# %%
# look through the resolution of image files
df_file_info = pd.DataFrame(image_files)
df_file_info.columns = ["image_link"]
print(f"df_file_info = {df_file_info.head(5)}")
# Out:
# df_file_info =                                         image_link
# 0  ../images/old_samples/photo-14610337-AfvlL7.jpg
# 1  ../images/old_samples/photo-14613473-oJlAGk.jpg
# 2  ../images/old_samples/photo-14613600-uzDqQq.jpg
# 3  ../images/old_samples/photo-14614603-V4bv1O.jpg
# 4  ../images/old_samples/photo-14615502-8O2X6l.jpg

# %%
X_old = load_array(image_files, min_size)

# y value is zero for old buildings
y_old = np.zeros((len(image_files),1))

print(f"X_old shape = {X_old.shape}")
print(f"y_old shape = {y_old.shape}")
# Out:
# c:\python37\lib\site-packages\PIL\TiffImagePlugin.py:788: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 2.
#   warnings.warn(str(msg))
# X_old shape = (250, 400, 400, 3)
# y_old shape = (250, 1)

# %%
df_y_old = pd.DataFrame(y_old, columns=["label"])
df_y_old["image_link"] = df_file_info["image_link"]
print(df_y_old.shape)
# Out:
# (250, 2)

# %%
# Photos of modern buildings

image_path = "../images/modern_samples/"
image_files = load_files(image_path)

# second batch of old buildings - 150 images of interior
image_path2 = "../images/modern_exterior/"
image_files2 = load_files(image_path2)

# concatenating 2 lists
image_files = image_files + image_files2

# set min_size = 400
min_size = 400

print(f"number of image_files = {len(image_files)}")
print(f"min_size = {min_size}")
# Out:
# number of image_files = 250
# min_size = 400

# %%
# look through the resolution of image files
df_file_info = pd.DataFrame(image_files)
df_file_info.columns = ["image_link"]
print(f"df_file_info = {df_file_info.head(5)}")
# Out:
# df_file_info =                                           image_link
# 0  ../images/modern_samples/photo-14607856-PBTR2E...
# 1  ../images/modern_samples/photo-14607975-aH71tJ...
# 2  ../images/modern_samples/photo-14608672-cQhyQn...
# 3  ../images/modern_samples/photo-14608758-AyTNmO...
# 4  ../images/modern_samples/photo-14608761-kbFlFq...

# %%
X_modern = load_array(image_files, min_size)

# y value is one for modern buildings
y_modern = np.ones((len(image_files),1))

print(f"X_modern shape = {X_modern.shape}")
print(f"y_modern shape = {y_modern.shape}")
# Out:
# X_modern shape = (250, 400, 400, 3)
# y_modern shape = (250, 1)

# %%
df_y_modern = pd.DataFrame(y_modern, columns=["label"])
df_y_modern["image_link"] = df_file_info["image_link"]
print(df_y_modern.shape)
# Out:
# (250, 2)

# %%
X = np.append(X_old, X_modern, axis = 0)
X.shape
# Out:
# (500, 400, 400, 3)

# %%
df_y = pd.concat([df_y_old, df_y_modern])
df_y.reset_index(drop=True, inplace=True)
df_y["id"] = df_y.index
print(df_y.shape)
df_y.tail(10)
# Out:
# (500, 3)
#      label                                         image_link   id
# 490    1.0  ../images/modern_exterior/photo-14748791-NXoBE...  490
# 491    1.0  ../images/modern_exterior/photo-14749036-KDpxC...  491
# 492    1.0  ../images/modern_exterior/photo-14749133-sPopz...  492
# 493    1.0  ../images/modern_exterior/photo-14749274-JCFg9...  493
# 494    1.0  ../images/modern_exterior/photo-14749594-D3S3G...  494
# 495    1.0  ../images/modern_exterior/photo-14749754-aMjBv...  495
# 496    1.0  ../images/modern_exterior/photo-14749941-ylAYu...  496
# 497    1.0  ../images/modern_exterior/photo-14750095-gpCbn...  497
# 498    1.0  ../images/modern_exterior/photo-14750097-vC2kr...  498
# 499    1.0  ../images/modern_exterior/photo-14750142-ZuvZh...  499

# %% [markdown]
# #### Train test split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, df_y, stratify=df_y["label"])
print(y_train.shape)
# Out:
# (375, 3)

# %%
# Baseline accuracy - 50%
y_train['label'].value_counts()
# Out:
# 1.0    188
# 0.0    187
# Name: label, dtype: int64

# %%
y_test.shape
# Out:
# (125, 3)

# %%
y_test['id'][:10]
# Out:
# 369    369
# 63      63
# 286    286
# 446    446
# 130    130
# 496    496
# 179    179
# 48      48
# 87      87
# 210    210
# Name: id, dtype: int64

# %%
plt.imshow(X_train[0])

# %% [markdown]
# #### Standard Scaler

# %%
X_train_flat = X_train.flatten().reshape(-1,1)
X_train_flat.shape
# Out:
# (180000000, 1)

# %%
X_test_flat = X_test.flatten().reshape(-1,1)
X_test_flat.shape
# Out:
# (60000000, 1)

# %%
ss = StandardScaler()
X_train_ss = ss.fit_transform(X_train_flat).reshape(X_train.shape)
X_test_ss = ss.transform(X_test_flat).reshape(X_test.shape)

# %% [markdown]
# ### Second run of model

# %%
# Instantiate a CNN.
cnn_model = Sequential()

# %%
# Add a convolutional layer.

cnn_model.add(Conv2D(filters = 6,            # number of filters
                     kernel_size = 3,        # height/width of filter
                     activation='relu',      # activation function 
                     input_shape=(min_size,min_size,3))) # shape of input (image)

# %%
cnn_model.add(MaxPooling2D(pool_size=(2,2))) # dimensions of region of pooling
cnn_model.add(Conv2D(16,
                     kernel_size=3,
                     activation='relu'))
cnn_model.add(MaxPooling2D(pool_size=(2,2)))
cnn_model.add(Flatten())
# Add a densely-connected layer with 128 neurons.
cnn_model.add(Dense(128, activation='relu'))
# Add a final layer with 2 neurons.
cnn_model.add(Dense(1, activation='sigmoid'))

# Compile model
cnn_model.compile(loss='binary_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])

# %%
cnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 398, 398, 6)       168
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 199, 199, 6)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 197, 197, 16)      880
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 98, 98, 16)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 153664)            0
# _________________________________________________________________
# dense (Dense)                (None, 128)               19669120
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 19,670,297
# Trainable params: 19,670,297
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fit model on training data
history = cnn_model.fit(X_train_ss,
                        y_train['label'],
                        batch_size=64,
                        validation_data=(X_test_ss, y_test['label']),
                        epochs=30,
                        verbose=1)
# Out:
# Epoch 1/30
# 6/6 [==============================] - 47s 6s/step - loss: 19.4427 - accuracy: 0.4903 - val_loss: 2.0452 - val_accuracy: 0.5040
# Epoch 2/30
# 6/6 [==============================] - 24s 4s/step - loss: 1.4413 - accuracy: 0.5353 - val_loss: 0.6870 - val_accuracy: 0.4960
# Epoch 3/30
# 6/6 [==============================] - 24s 4s/step - loss: 0.6641 - accuracy: 0.6104 - val_loss: 0.5816 - val_accuracy: 0.7120
# Epoch 4/30
# 6/6 [==============================] - 23s 4s/step - loss: 0.5905 - accuracy: 0.7217 - val_loss: 0.5498 - val_accuracy: 0.7280
# Epoch 5/30
# 6/6 [==============================] - 23s 4s/step - loss: 0.5360 - accuracy: 0.7126 - val_loss: 0.5113 - val_accuracy: 0.7360
# Epoch 6/30
# 6/6 [==============================] - 22s 4s/step - loss: 0.4578 - accuracy: 0.7734 - val_loss: 0.5170 - val_accuracy: 0.7520
# Epoch 7/30
# 6/6 [==============================] - 22s 4s/step - loss: 0.3993 - accuracy: 0.7728 - val_loss: 0.4912 - val_accuracy: 0.7360
# Epoch 8/30
# 6/6 [==============================] - 22s 4s/step - loss: 0.3458 - accuracy: 0.8353 - val_loss: 0.5569 - val_accuracy: 0.7280
# Epoch 9/30
# 6/6 [==============================] - 22s 4s/step - loss: 0.2941 - accuracy: 0.8437 - val_loss: 0.5356 - val_accuracy: 0.7520
# Epoch 10/30
# 6/6 [==============================] - 22s 4s/step - loss: 0.2838 - accuracy: 0.8561 - val_loss: 0.4899 - val_accuracy: 0.7760
# Epoch 11/30
# 6/6 [==============================] - 21s 4s/step - loss: 0.2063 - accuracy: 0.9150 - val_loss: 0.4924 - val_accuracy: 0.7600
# Epoch 12/30
# 6/6 [==============================] - 21s 4s/step - loss: 0.1576 - accuracy: 0.9610 - val_loss: 0.4989 - val_accuracy: 0.7360
# Epoch 13/30
# 6/6 [==============================] - 21s 4s/step - loss: 0.1245 - accuracy: 0.9726 - val_loss: 0.5052 - val_accuracy: 0.7360
# Epoch 14/30
# 6/6 [==============================] - 21s 4s/step - loss: 0.1089 - accuracy: 0.9909 - val_loss: 0.5101 - val_accuracy: 0.7440
# Epoch 15/30
# 6/6 [==============================] - 21s 4s/step - loss: 0.0877 - accuracy: 0.9880 - val_loss: 0.5158 - val_accuracy: 0.7440
# Epoch 16/30
# 6/6 [==============================] - 21s 3s/step - loss: 0.0651 - accuracy: 0.9873 - val_loss: 0.5142 - val_accuracy: 0.7280
# Epoch 17/30
# 6/6 [==============================] - 21s 4s/step - loss: 0.0535 - accuracy: 0.9964 - val_loss: 0.5370 - val_accuracy: 0.7280
# Epoch 18/30
# 6/6 [==============================] - 21s 4s/step - loss: 0.0470 - accuracy: 0.9941 - val_loss: 0.5317 - val_accuracy: 0.7600
# Epoch 19/30
# 6/6 [==============================] - 21s 4s/step - loss: 0.0314 - accuracy: 0.9992 - val_loss: 0.5434 - val_accuracy: 0.7600
# Epoch 20/30
# 6/6 [==============================] - 21s 4s/step - loss: 0.0280 - accuracy: 0.9967 - val_loss: 0.5513 - val_accuracy: 0.7360
# Epoch 21/30
# 6/6 [==============================] - 21s 4s/step - loss: 0.0256 - accuracy: 1.0000 - val_loss: 0.5606 - val_accuracy: 0.7360
# Epoch 22/30
# 6/6 [==============================] - 22s 4s/step - loss: 0.0234 - accuracy: 1.0000 - val_loss: 0.5719 - val_accuracy: 0.7440
# Epoch 23/30
# 6/6 [==============================] - 23s 4s/step - loss: 0.0239 - accuracy: 1.0000 - val_loss: 0.5797 - val_accuracy: 0.7440
# Epoch 24/30
# 6/6 [==============================] - 22s 4s/step - loss: 0.0182 - accuracy: 1.0000 - val_loss: 0.5850 - val_accuracy: 0.7360
# Epoch 25/30
# 6/6 [==============================] - 22s 4s/step - loss: 0.0170 - accuracy: 0.9975 - val_loss: 0.5946 - val_accuracy: 0.7440
# Epoch 26/30
# 6/6 [==============================] - 20s 3s/step - loss: 0.0160 - accuracy: 1.0000 - val_loss: 0.5962 - val_accuracy: 0.7360
# Epoch 27/30
# 6/6 [==============================] - 15s 3s/step - loss: 0.0183 - accuracy: 1.0000 - val_loss: 0.6157 - val_accuracy: 0.7440
# Epoch 28/30
# 6/6 [==============================] - 18s 3s/step - loss: 0.0164 - accuracy: 1.0000 - val_loss: 0.6085 - val_accuracy: 0.7520
# Epoch 29/30
# 6/6 [==============================] - 19s 3s/step - loss: 0.0169 - accuracy: 1.0000 - val_loss: 0.6225 - val_accuracy: 0.7440
# Epoch 30/30
# 6/6 [==============================] - 18s 3s/step - loss: 0.0136 - accuracy: 1.0000 - val_loss: 0.6238 - val_accuracy: 0.7440

# %%
train_loss = history.history['loss']
test_loss = history.history['val_loss']
plt.figure(figsize=(12, 8))
plt.plot(train_loss, label='Training loss', color='navy')
plt.plot(test_loss, label='Testing loss', color='skyblue')
plt.legend();

# %% [markdown]
# #### List out the images of misclassification - test images

# %%
y_test.head(10)
# Out:
#      label                                         image_link   id
# 369    1.0  ../images/modern_exterior/photo-14726446-BBxTP...  369
# 63     0.0    ../images/old_samples/photo-14683927-fbRTa8.jpg   63
# 286    1.0  ../images/modern_samples/photo-14614916-1P6rqr...  286
# 446    1.0  ../images/modern_exterior/photo-14743296-VxaFx...  446
# 130    0.0   ../images/old_interior/photo-14615793-T1U07w.jpg  130
# 496    1.0  ../images/modern_exterior/photo-14749941-ylAYu...  496
# 179    0.0   ../images/old_interior/photo-14636050-RB8GSC.jpg  179
# 48     0.0    ../images/old_samples/photo-14659450-KYGvb7.jpg   48
# 87     0.0    ../images/old_samples/photo-14712501-rb2HVi.jpg   87
# 210    0.0   ../images/old_interior/photo-14639291-EIkv8f.jpg  210

# %%
y_pred = cnn_model.predict(X_test_ss)

# %%
y_pred.shape
# Out:
# (125, 1)

# %%
y_test['pred'] = y_pred.round()
y_test['prob'] = y_pred.round(3)
y_test.head(10)
# Out:
# c:\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# c:\python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      label                                         image_link   id  pred  \
# 369    1.0  ../images/modern_exterior/photo-14726446-BBxTP...  369   1.0
# 63     0.0    ../images/old_samples/photo-14683927-fbRTa8.jpg   63   0.0
# 286    1.0  ../images/modern_samples/photo-14614916-1P6rqr...  286   0.0
# 446    1.0  ../images/modern_exterior/photo-14743296-VxaFx...  446   1.0
# 130    0.0   ../images/old_interior/photo-14615793-T1U07w.jpg  130   1.0
# 496    1.0  ../images/modern_exterior/photo-14749941-ylAYu...  496   1.0
# 179    0.0   ../images/old_interior/photo-14636050-RB8GSC.jpg  179   0.0
# 48     0.0    ../images/old_samples/photo-14659450-KYGvb7.jpg   48   0.0
# 87     0.0    ../images/old_samples/photo-14712501-rb2HVi.jpg   87   0.0
# 210    0.0   ../images/old_interior/photo-14639291-EIkv8f.jpg  210   1.0
#
#       prob
# 369  1.000
# 63   0.000
# 286  0.214
# 446  0.915
# 130  0.697
# 496  1.000
# 179  0.023
# 48   0.000
# 87   0.000
# 210  0.519

# %%
# count the number of photos misclassified in y_test
y_test_misclassified = y_test[["image_link", "label", "pred", "prob"]][y_test["label"] != y_test["pred"]]

print(f"total number in y_test: {y_test.shape[0]}")
print(f"misclassified in y_test: {y_test_misclassified.shape[0]}")
y_test_misclassified.head()
# Out:
# total number in y_test: 125
# misclassified in y_test: 32
#                                             image_link  label  pred   prob
# 286  ../images/modern_samples/photo-14614916-1P6rqr...    1.0   0.0  0.214
# 130   ../images/old_interior/photo-14615793-T1U07w.jpg    0.0   1.0  0.697
# 210   ../images/old_interior/photo-14639291-EIkv8f.jpg    0.0   1.0  0.519
# 188   ../images/old_interior/photo-14636562-DGqBl9.jpg    0.0   1.0  0.730
# 14     ../images/old_samples/photo-14635306-6MWiMM.jpg    0.0   1.0  0.924

# %%
# show the first 20 photos misclassified in y_test
display_no = min(20, y_test_misclassified.shape[0])

fig, ax = plt.subplots(ceil(display_no/2), 2, figsize=(8,32))
j=0
for i in y_test_misclassified.index[:display_no]:
    row = j//2
    col = j%2
    image_link = y_test_misclassified.loc[i, "image_link"]
    ax[row][col].imshow(io.imread(image_link))
    ax[row][col].set_title("label:" + str(y_test_misclassified.loc[i, "label"]) + ", pred:" + str(y_test_misclassified.loc[i, "pred"]) + "prob:"  + str(y_test_misclassified.loc[i, "prob"]))
    ax[row][col].axis('off')
    j += 1

print(j)
# Out:
# c:\python37\lib\site-packages\PIL\TiffImagePlugin.py:788: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 2.
#   warnings.warn(str(msg))
# 20

# %% [markdown]
# ### Saving the model

# %%
model_tag = "model2"

# %%
# save the scaler
pickle.dump(ss, open('../models/' + model_tag + '/scaler.pkl', 'wb'))

# %%
# Save the model
model = cnn_model

path = '../models/' + model_tag + '/'
model.save(path)
# Out:
# INFO:tensorflow:Assets written to: ../models/model2/assets
