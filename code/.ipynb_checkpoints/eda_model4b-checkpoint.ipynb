# %% [markdown]
# # UK Property Image Classification
# ### EDA model 4b
#
# ---

# %% [markdown]
# #### Data:
# Exterior images only, 250 images each class
#
# #### Model:
# Convoluted Neural Nets
# - Use standard scaler
# - Use early stopper
# - Remove dropout
# - Dense layer neuron changed to 64 from 128
#
# #### Initial model results:
# [ ]

# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os
from math import ceil
import random

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder

from skimage import io
from skimage import color
from skimage.transform import rescale, resize, downscale_local_mean

import pickle

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import EarlyStopping

# %%
# For reproducibility
np.random.seed(42)

# %%
# function to load folder into arrays and  then it returns that same array

def load_files(path):
    # Put files into lists and return them as one list of size 4
    image_files = os.listdir(path)
    image_files = [path + x for x in image_files]
    return image_files

# %%
# feeding images into numpy ndarray

def load_array(image_files, min_size):
    X = np.array([])
    for file in image_files:
        try:
            img = io.imread(file)
            img_resized = resize(img, (min_size,min_size), anti_aliasing=True)
            if X.shape[0] == 0:
                X = np.array([img_resized])
            else:
                X = np.append(X, [img_resized], axis = 0)
        
        except:
            print("image error: ", file)
    return X

# %%
def load_more_images(criteria, k):
    
    #default csv file of record
    csv = '../data/more_images.csv'
    images = pd.read_csv(csv)
    images.fillna(0, inplace=True)
    
    for key, value in criteria.items():
        images = images[images[key]==value]
    
    if k>len(images):
        print("Number of images is less than k")
    selected = random.choices(images["image_link"].to_list(), k=k)
    
    return selected

# %% [markdown]
# #### Load the training data - old buildings

# %%
# Photos of old or period buildings

image_path = "../images/old_samples/"
image_files = load_files(image_path)

# third batch - more images - 191 exterior
criteria = {"ext":1., "new":0.}
k=161
image_files2 = load_more_images(criteria, k)

# concatenating 2 lists
image_files = image_files + image_files2

# set min_size = 400
min_size = 400

print(f"number of image_files = {len(image_files)}")
print(f"min_size = {min_size}")
# Out:
# Number of images is less than k
# number of image_files = 280
# min_size = 400

# %%
image_files[-10:]
# Out:
# ['../../capstone_more_images/old/photo-14649564-qHvdKD.jpg',
#  '../../capstone_more_images/old/photo-14670171-FcMGcX.jpg',
#  '../../capstone_more_images/old/photo-14674540-qq33mE.jpg',
#  '../../capstone_more_images/old/photo-14636469-dD53bQ.jpg',
#  '../../capstone_more_images/modern/photo-14665366-GyGfpK.jpg',
#  '../../capstone_more_images/old/photo-14710827-9a01IX.jpg',
#  '../../capstone_more_images/modern/photo-14715260-aEJQzr.jpg',
#  '../../capstone_more_images/old/photo-14675772-qQCBbb.jpg',
#  '../../capstone_more_images/old/photo-14714803-PExBXe.jpg',
#  '../../capstone_more_images/old/photo-14631246-hpFkGF.jpg']

# %%
# record image links in dataframe
df_file_info = pd.DataFrame(image_files)
df_file_info.columns = ["image_link"]
print(f"df_file_info = {df_file_info.head(5)}")
# Out:
# df_file_info =                                         image_link
# 0  ../images/old_samples/photo-14610337-AfvlL7.jpg
# 1  ../images/old_samples/photo-14613473-oJlAGk.jpg
# 2  ../images/old_samples/photo-14613600-uzDqQq.jpg
# 3  ../images/old_samples/photo-14614603-V4bv1O.jpg
# 4  ../images/old_samples/photo-14615502-8O2X6l.jpg

# %%
X_old = load_array(image_files, min_size)

# y value is zero for old buildings
y_old = np.zeros((len(image_files),1))

print(f"X_old shape = {X_old.shape}")
print(f"y_old shape = {y_old.shape}")
# Out:
# c:\python37\lib\site-packages\PIL\TiffImagePlugin.py:788: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 2.
#   warnings.warn(str(msg))
# X_old shape = (280, 400, 400, 3)
# y_old shape = (280, 1)

# %%
df_y_old = pd.DataFrame(y_old, columns=["label"])
df_y_old["image_link"] = df_file_info["image_link"]
print(df_y_old.shape)
# Out:
# (280, 2)

# %%
# Photos of modern buildings

# first batch - modern exterior
image_path = "../images/modern_exterior/"
image_files = load_files(image_path)

# second batch - more images - 130 exterior
criteria = {"ext":1., "new":1.}
k=100
image_files2 = load_more_images(criteria, k)

# concatenating 2 lists
image_files = image_files + image_files2

# set min_size = 400
min_size = 400

print(f"number of image_files = {len(image_files)}")
print(f"min_size = {min_size}")
# Out:
# Number of images is less than k
# number of image_files = 280
# min_size = 400

# %%
# record image links in dataframe
df_file_info = pd.DataFrame(image_files)
df_file_info.columns = ["image_link"]
print(f"df_file_info = {df_file_info.head(5)}")
# Out:
# df_file_info =                                           image_link
# 0  ../images/modern_exterior/photo-14723285-Ij1qL...
# 1  ../images/modern_exterior/photo-14723721-06TtP...
# 2  ../images/modern_exterior/photo-14723756-sqnnq...
# 3  ../images/modern_exterior/photo-14723762-tK2Vv...
# 4  ../images/modern_exterior/photo-14723907-wPr2I...

# %%
X_modern = load_array(image_files, min_size)

# y value is one for modern buildings
y_modern = np.ones((len(image_files),1))

print(f"X_modern shape = {X_modern.shape}")
print(f"y_modern shape = {y_modern.shape}")
# Out:
# X_modern shape = (280, 400, 400, 3)
# y_modern shape = (280, 1)

# %%
df_y_modern = pd.DataFrame(y_modern, columns=["label"])
df_y_modern["image_link"] = df_file_info["image_link"]
print(df_y_modern.shape)
# Out:
# (280, 2)

# %%
X = np.append(X_old, X_modern, axis = 0)
X.shape
# Out:
# (560, 400, 400, 3)

# %%
np.min(X)
# Out:
# 0.0

# %%
np.max(X)
# Out:
# 1.0

# %% [markdown]
# Note: range of values is 0 to 1; ie min max standard scaling in place

# %%
df_y = pd.concat([df_y_old, df_y_modern])
df_y.reset_index(drop=True, inplace=True)
df_y["id"] = df_y.index
print(df_y.shape)
df_y.tail(10)
# Out:
# (560, 3)
#      label                                         image_link   id
# 550    1.0  ../../capstone_more_images/modern/photo-146771...  550
# 551    1.0  ../../capstone_more_images/modern/photo-146599...  551
# 552    1.0  ../../capstone_more_images/old/photo-14713001-...  552
# 553    1.0  ../../capstone_more_images/old/photo-14687164-...  553
# 554    1.0  ../../capstone_more_images/old/photo-14713001-...  554
# 555    1.0  ../../capstone_more_images/modern/photo-146486...  555
# 556    1.0  ../../capstone_more_images/modern/photo-147125...  556
# 557    1.0  ../../capstone_more_images/modern/photo-146486...  557
# 558    1.0  ../../capstone_more_images/modern/photo-146758...  558
# 559    1.0  ../../capstone_more_images/modern/photo-146603...  559

# %% [markdown]
# #### Train test split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, df_y, stratify=df_y["label"])
print(y_train.shape)
# Out:
# (420, 3)

# %%
# Baseline accuracy - 50%
y_train['label'].value_counts()
# Out:
# 1.0    210
# 0.0    210
# Name: label, dtype: int64

# %%
y_test.shape
# Out:
# (140, 3)

# %%
y_test['id'][:10]
# Out:
# 129    129
# 455    455
# 207    207
# 133    133
# 376    376
# 328    328
# 407    407
# 149    149
# 473    473
# 17      17
# Name: id, dtype: int64

# %%
plt.imshow(X_train[0])

# %% [markdown]
# #### Standard Scaler

# %%
X_train_flat = X_train.flatten().reshape(-1,1)
X_train_flat.shape
# Out:
# (201600000, 1)

# %%
X_test_flat = X_test.flatten().reshape(-1,1)
X_test_flat.shape
# Out:
# (67200000, 1)

# %%
ss = StandardScaler()
X_train_ss = ss.fit_transform(X_train_flat).reshape(X_train.shape)
X_test_ss = ss.transform(X_test_flat).reshape(X_test.shape)

X_train_ss = X_train
X_test_ss = X_test

# %% [markdown]
# ### CNN model

# %%
# Instantiate a CNN.
cnn_model = Sequential()

# %%
# Add a convolutional layer.

cnn_model.add(Conv2D(filters = 6,            # number of filters
                     kernel_size = 3,        # height/width of filter
                     activation='relu',      # activation function 
                     input_shape=(min_size,min_size,3))) # shape of input (image)

# %%
cnn_model.add(MaxPooling2D(pool_size=(2,2))) # dimensions of region of pooling
cnn_model.add(Conv2D(16,
                     kernel_size=3,
                     activation='relu'))
cnn_model.add(MaxPooling2D(pool_size=(2,2)))
cnn_model.add(Flatten())
# Add a densely-connected layer with 128 neurons.
cnn_model.add(Dense(64, activation='relu'))
# Add a final layer with 2 neurons.
cnn_model.add(Dense(1, activation='sigmoid'))

# Early stopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)

# Compile model
cnn_model.compile(loss='binary_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])

# %%
cnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 398, 398, 6)       168
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 199, 199, 6)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 197, 197, 16)      880
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 98, 98, 16)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 153664)            0
# _________________________________________________________________
# dense (Dense)                (None, 64)                9834560
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 9,835,673
# Trainable params: 9,835,673
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fit model on training data
history = cnn_model.fit(X_train_ss,
                        y_train['label'],
                        batch_size=64,
                        validation_data=(X_test_ss, y_test['label']),
                        epochs=30,
                        callbacks=[es],
                        verbose=1)
# Out:
# Epoch 1/30
# 7/7 [==============================] - 31s 4s/step - loss: 3.9832 - accuracy: 0.5446 - val_loss: 4.8614 - val_accuracy: 0.5000
# Epoch 2/30
# 7/7 [==============================] - 17s 2s/step - loss: 2.7456 - accuracy: 0.5599 - val_loss: 0.7094 - val_accuracy: 0.7714
# Epoch 3/30
# 7/7 [==============================] - 16s 2s/step - loss: 1.0168 - accuracy: 0.6374 - val_loss: 0.5489 - val_accuracy: 0.7357
# Epoch 4/30
# 7/7 [==============================] - 16s 2s/step - loss: 0.6438 - accuracy: 0.6833 - val_loss: 0.5206 - val_accuracy: 0.6571
# Epoch 5/30
# 7/7 [==============================] - 16s 2s/step - loss: 0.3771 - accuracy: 0.8453 - val_loss: 0.4122 - val_accuracy: 0.8000
# Epoch 6/30
# 7/7 [==============================] - 16s 2s/step - loss: 0.2746 - accuracy: 0.8990 - val_loss: 0.3784 - val_accuracy: 0.8286
# Epoch 7/30
# 7/7 [==============================] - 16s 2s/step - loss: 0.1784 - accuracy: 0.9617 - val_loss: 0.4470 - val_accuracy: 0.7786
# Epoch 8/30
# 7/7 [==============================] - 16s 2s/step - loss: 0.1209 - accuracy: 0.9895 - val_loss: 0.3735 - val_accuracy: 0.8429
# Epoch 9/30
# 7/7 [==============================] - 16s 2s/step - loss: 0.0665 - accuracy: 0.9928 - val_loss: 0.4896 - val_accuracy: 0.7643
# Epoch 10/30
# 7/7 [==============================] - 16s 2s/step - loss: 0.0407 - accuracy: 0.9994 - val_loss: 0.3819 - val_accuracy: 0.8000
# Epoch 11/30
# 7/7 [==============================] - 16s 2s/step - loss: 0.0238 - accuracy: 1.0000 - val_loss: 0.4582 - val_accuracy: 0.7929
# Epoch 12/30
# 7/7 [==============================] - 16s 2s/step - loss: 0.0121 - accuracy: 1.0000 - val_loss: 0.4672 - val_accuracy: 0.7929
# Epoch 13/30
# 7/7 [==============================] - 16s 2s/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.5418 - val_accuracy: 0.7857
# Epoch 00013: early stopping

# %%
train_loss = history.history['loss']
test_loss = history.history['val_loss']
plt.figure(figsize=(12, 8))
plt.plot(train_loss, label='Training loss', color='navy')
plt.plot(test_loss, label='Testing loss', color='skyblue')
plt.legend();

# %% [markdown]
# #### List out the images of misclassification - test images

# %%
y_test.head(10)
# Out:
#      label                                         image_link   id
# 129    0.0  ../../capstone_more_images/old/photo-14629232-...  129
# 455    1.0  ../../capstone_more_images/modern/photo-147044...  455
# 207    0.0  ../../capstone_more_images/old/photo-14669588-...  207
# 133    0.0  ../../capstone_more_images/old/photo-14710797-...  133
# 376    1.0  ../images/modern_exterior/photo-14743296-VxaFx...  376
# 328    1.0  ../images/modern_exterior/photo-14728948-DDhZK...  328
# 407    1.0  ../images/modern_exterior/photo-14746724-PD2Mi...  407
# 149    0.0  ../../capstone_more_images/old/photo-14673957-...  149
# 473    1.0  ../../capstone_more_images/modern/photo-146364...  473
# 17     0.0    ../images/old_samples/photo-14639139-0umZNo.jpg   17

# %%
y_pred = cnn_model.predict(X_test_ss)

# %%
y_pred.shape
# Out:
# (140, 1)

# %%
y_test['pred'] = y_pred.round()
y_test['prob'] = y_pred.round(3)
y_test.head(10)
# Out:
# c:\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# c:\python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      label                                         image_link   id  pred  \
# 129    0.0  ../../capstone_more_images/old/photo-14629232-...  129   0.0
# 455    1.0  ../../capstone_more_images/modern/photo-147044...  455   1.0
# 207    0.0  ../../capstone_more_images/old/photo-14669588-...  207   0.0
# 133    0.0  ../../capstone_more_images/old/photo-14710797-...  133   0.0
# 376    1.0  ../images/modern_exterior/photo-14743296-VxaFx...  376   1.0
# 328    1.0  ../images/modern_exterior/photo-14728948-DDhZK...  328   1.0
# 407    1.0  ../images/modern_exterior/photo-14746724-PD2Mi...  407   1.0
# 149    0.0  ../../capstone_more_images/old/photo-14673957-...  149   0.0
# 473    1.0  ../../capstone_more_images/modern/photo-146364...  473   1.0
# 17     0.0    ../images/old_samples/photo-14639139-0umZNo.jpg   17   1.0
#
#       prob
# 129  0.002
# 455  0.999
# 207  0.002
# 133  0.003
# 376  0.999
# 328  1.000
# 407  0.997
# 149  0.003
# 473  1.000
# 17   0.865

# %%
# count the number of photos classified properly in y_test
y_test_classified = y_test[["image_link", "label", "pred", "prob"]][y_test["label"] == y_test["pred"]]

print(f"total number in y_test: {y_test.shape[0]}")
print(f"classified properly in y_test: {y_test_classified.shape[0]}")
y_test_classified.head()
# Out:
# total number in y_test: 140
# classified properly in y_test: 110
#                                             image_link  label  pred   prob
# 129  ../../capstone_more_images/old/photo-14629232-...    0.0   0.0  0.002
# 455  ../../capstone_more_images/modern/photo-147044...    1.0   1.0  0.999
# 207  ../../capstone_more_images/old/photo-14669588-...    0.0   0.0  0.002
# 133  ../../capstone_more_images/old/photo-14710797-...    0.0   0.0  0.003
# 376  ../images/modern_exterior/photo-14743296-VxaFx...    1.0   1.0  0.999

# %%
# show the first 20 photos classified properly in y_test
display_no = min(20, y_test_classified.shape[0])

fig, ax = plt.subplots(ceil(display_no/2), 2, figsize=(8,32))
j=0
for i in y_test_classified.index[:display_no]:
    row = j//2
    col = j%2
    image_link = y_test_classified.loc[i, "image_link"]
    ax[row][col].imshow(io.imread(image_link))
    ax[row][col].set_title("label:" + str(y_test_classified.loc[i, "label"]) + ", pred:" + str(y_test_classified.loc[i, "pred"]) + "prob:"  + str(y_test_classified.loc[i, "prob"]))
    ax[row][col].axis('off')
    j += 1

print(j)
# Out:
# 20

# %%
# count the number of photos misclassified in y_test
y_test_misclassified = y_test[["image_link", "label", "pred", "prob"]][y_test["label"] != y_test["pred"]]

print(f"total number in y_test: {y_test.shape[0]}")
print(f"misclassified in y_test: {y_test_misclassified.shape[0]}")
y_test_misclassified.head()
# Out:
# total number in y_test: 140
# misclassified in y_test: 30
#                                             image_link  label  pred   prob
# 17     ../images/old_samples/photo-14639139-0umZNo.jpg    0.0   1.0  0.865
# 494  ../../capstone_more_images/modern/photo-146758...    1.0   0.0  0.260
# 374  ../images/modern_exterior/photo-14743190-x4ell...    1.0   0.0  0.347
# 163  ../../capstone_more_images/modern/photo-146722...    0.0   1.0  0.993
# 274  ../../capstone_more_images/modern/photo-146653...    0.0   1.0  0.966

# %%
# show the first 20 photos misclassified in y_test
display_no = min(20, y_test_misclassified.shape[0])

fig, ax = plt.subplots(ceil(display_no/2), 2, figsize=(8,32))
j=0
for i in y_test_misclassified.index[:display_no]:
    row = j//2
    col = j%2
    image_link = y_test_misclassified.loc[i, "image_link"]
    ax[row][col].imshow(io.imread(image_link))
    ax[row][col].set_title("label:" + str(y_test_misclassified.loc[i, "label"]) + ", pred:" + str(y_test_misclassified.loc[i, "pred"]) + "prob:"  + str(y_test_misclassified.loc[i, "prob"]))
    ax[row][col].axis('off')
    j += 1

print(j)
# Out:
# 20

# %% [markdown]
# ### Saving the model

# %%
model_tag = "model4b"

# %%
# Save the model
model = cnn_model

path = '../models/' + model_tag + '/'
model.save(path)
# Out:
# INFO:tensorflow:Assets written to: ../models/model4b/assets

# %%
# save the scaler
pickle.dump(ss, open('../models/' + model_tag + '/scaler.pkl', 'wb'))
