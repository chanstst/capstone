# %% [markdown]
# # UK Property Image Classification
# ### EDA model 4a
#
# ---

# %% [markdown]
# #### Data:
# Exterior images only, 250 images each class
#
# #### Model:
# Convoluted Neural Nets
# - Use standard scaler
# - Use early stopper
# - Use dropout
#
# #### Initial model results:
# [ ]
#
# #### Training model with more images:
# [ ]

# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os
from math import ceil
import random

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder

from skimage import io
from skimage import color
from skimage.transform import rescale, resize, downscale_local_mean

import pickle

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import EarlyStopping

# %%
# For reproducibility
np.random.seed(42)

# %%
# function to load folder into arrays and  then it returns that same array

def load_files(path):
    # Put files into lists and return them as one list of size 4
    image_files = os.listdir(path)
    image_files = [path + x for x in image_files]
    return image_files

# %%
# feeding images into numpy ndarray

def load_array(image_files, min_size):
    X = np.array([])
    for file in image_files:
        try:
            img = io.imread(file)
            img_resized = resize(img, (min_size,min_size), anti_aliasing=True)
            if X.shape[0] == 0:
                X = np.array([img_resized])
            else:
                X = np.append(X, [img_resized], axis = 0)
        
        except:
            print("image error: ", file)
    return X

# %%
def load_more_images(criteria, k):
    
    #default csv file of record
    csv = '../data/more_images.csv'
    images = pd.read_csv(csv)
    images.fillna(0, inplace=True)
    
    for key, value in criteria.items():
        images = images[images[key]==value]
    
    if k>len(images):
        print("Number of images is less than k")
    selected = random.choices(images["image_link"].to_list(), k=k)
    
    return selected

# %% [markdown]
# #### Load the training data - old buildings

# %%
# Photos of old or period buildings

image_path = "../images/old_samples/"
image_files = load_files(image_path)

# third batch - more images - 125 exterior
criteria = {"ext":1., "new":0.}
k=125
image_files2 = load_more_images(criteria, k)

# concatenating 2 lists
image_files = image_files + image_files2

# set min_size = 400
min_size = 400

print(f"number of image_files = {len(image_files)}")
print(f"min_size = {min_size}")
# Out:
# number of image_files = 501
# min_size = 400

# %%
image_files[-10:]
# Out:
# ['../../capstone_more_images/old/photo-14680257-Jgujkw.jpg',
#  '../../capstone_more_images/old/photo-14614016-MqSeaZ.jpg',
#  '../../capstone_more_images/old/photo-14697730-du0Dm2.jpg',
#  '../../capstone_more_images/old/photo-14680929-Syl1i1.jpg',
#  '../../capstone_more_images/old/photo-14693244-ygRXGL.jpg',
#  '../../capstone_more_images/old/photo-14716485-SNplHb.jpg',
#  '../../capstone_more_images/old/photo-14614016-MqSeaZ.jpg',
#  '../../capstone_more_images/old/photo-14670280-f0tXbn.jpg',
#  '../../capstone_more_images/old/photo-14712869-lwtJCa.jpg',
#  '../../capstone_more_images/old/photo-14660701-kE8dvt.jpg']

# %%
# record image links in dataframe
df_file_info = pd.DataFrame(image_files)
df_file_info.columns = ["image_link"]
print(f"df_file_info = {df_file_info.head(5)}")
# Out:
# df_file_info =                                         image_link
# 0  ../images/old_samples/photo-14610337-AfvlL7.jpg
# 1  ../images/old_samples/photo-14613473-oJlAGk.jpg
# 2  ../images/old_samples/photo-14613600-uzDqQq.jpg
# 3  ../images/old_samples/photo-14614603-V4bv1O.jpg
# 4  ../images/old_samples/photo-14615502-8O2X6l.jpg

# %%
X_old = load_array(image_files, min_size)

# y value is zero for old buildings
y_old = np.zeros((len(image_files),1))

print(f"X_old shape = {X_old.shape}")
print(f"y_old shape = {y_old.shape}")
# Out:
# c:\python37\lib\site-packages\PIL\TiffImagePlugin.py:788: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 2.
#   warnings.warn(str(msg))
# X_old shape = (501, 400, 400, 3)
# y_old shape = (501, 1)

# %%
df_y_old = pd.DataFrame(y_old, columns=["label"])
df_y_old["image_link"] = df_file_info["image_link"]
print(df_y_old.shape)
# Out:
# (501, 2)

# %%
# Photos of modern buildings

# first batch - modern exterior
image_path = "../images/modern_exterior/"
image_files = load_files(image_path)

# second batch - more images - 130 exterior
criteria = {"ext":1., "new":1.}
k=130
image_files2 = load_more_images(criteria, k)

# concatenating 2 lists
image_files = image_files + image_files2

# set min_size = 400
min_size = 400

print(f"number of image_files = {len(image_files)}")
print(f"min_size = {min_size}")
# Out:
# Number of images is less than k
# number of image_files = 500
# min_size = 400

# %%
# record image links in dataframe
df_file_info = pd.DataFrame(image_files)
df_file_info.columns = ["image_link"]
print(f"df_file_info = {df_file_info.head(5)}")
# Out:
# df_file_info =                                           image_link
# 0  ../images/modern_samples/photo-14607856-PBTR2E...
# 1  ../images/modern_samples/photo-14607975-aH71tJ...
# 2  ../images/modern_samples/photo-14608672-cQhyQn...
# 3  ../images/modern_samples/photo-14608758-AyTNmO...
# 4  ../images/modern_samples/photo-14608761-kbFlFq...

# %%
X_modern = load_array(image_files, min_size)

# y value is one for modern buildings
y_modern = np.ones((len(image_files),1))

print(f"X_modern shape = {X_modern.shape}")
print(f"y_modern shape = {y_modern.shape}")
# Out:
# c:\python37\lib\site-packages\PIL\TiffImagePlugin.py:788: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 2.
#   warnings.warn(str(msg))
# X_modern shape = (500, 400, 400, 3)
# y_modern shape = (500, 1)

# %%
df_y_modern = pd.DataFrame(y_modern, columns=["label"])
df_y_modern["image_link"] = df_file_info["image_link"]
print(df_y_modern.shape)
# Out:
# (500, 2)

# %%
X = np.append(X_old, X_modern, axis = 0)
X.shape
# Out:
# (1001, 400, 400, 3)

# %%
np.min(X)
# Out:
# 0.0

# %%
np.max(X)
# Out:
# 1.0

# %% [markdown]
# Note: range of values is 0 to 1; ie min max standard scaling in place

# %%
df_y = pd.concat([df_y_old, df_y_modern])
df_y.reset_index(drop=True, inplace=True)
df_y["id"] = df_y.index
print(df_y.shape)
df_y.tail(10)
# Out:
# (1001, 3)
#       label                                         image_link    id
# 991     1.0  ../../capstone_more_images/modern/photo-146498...   991
# 992     1.0  ../../capstone_more_images/old/photo-14678892-...   992
# 993     1.0  ../../capstone_more_images/modern/photo-146392...   993
# 994     1.0  ../../capstone_more_images/modern/photo-146424...   994
# 995     1.0  ../../capstone_more_images/modern/photo-146583...   995
# 996     1.0  ../../capstone_more_images/modern/photo-146825...   996
# 997     1.0  ../../capstone_more_images/modern/photo-146683...   997
# 998     1.0  ../../capstone_more_images/modern/photo-146777...   998
# 999     1.0  ../../capstone_more_images/modern/photo-146598...   999
# 1000    1.0  ../../capstone_more_images/modern/photo-146987...  1000

# %% [markdown]
# #### Train test split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, df_y, stratify=df_y["label"])
print(y_train.shape)
# Out:
# (750, 3)

# %%
# Baseline accuracy - 50%
y_train['label'].value_counts()
# Out:
# 0.0    375
# 1.0    375
# Name: label, dtype: int64

# %%
y_test.shape
# Out:
# (251, 3)

# %%
y_test['id'][:10]
# Out:
# 80      80
# 191    191
# 259    259
# 500    500
# 300    300
# 836    836
# 576    576
# 273    273
# 908    908
# 404    404
# Name: id, dtype: int64

# %%
plt.imshow(X_train[0])

# %% [markdown]
# #### Standard Scaler (skipped)

# %%
X_train_flat = X_train.flatten().reshape(-1,1)
X_train_flat.shape
# Out:
# (360000000, 1)

# %%
X_test_flat = X_test.flatten().reshape(-1,1)
X_test_flat.shape
# Out:
# (120480000, 1)

# %%
ss = StandardScaler()
X_train_ss = ss.fit_transform(X_train_flat).reshape(X_train.shape)
X_test_ss = ss.transform(X_test_flat).reshape(X_test.shape)

X_train_ss = X_train
X_test_ss = X_test

# %% [markdown]
# ### CNN model

# %%
# Instantiate a CNN.
cnn_model = Sequential()

# %%
# Add a convolutional layer.

cnn_model.add(Conv2D(filters = 6,            # number of filters
                     kernel_size = 3,        # height/width of filter
                     activation='relu',      # activation function 
                     input_shape=(min_size,min_size,3))) # shape of input (image)

# %%
cnn_model.add(MaxPooling2D(pool_size=(2,2))) # dimensions of region of pooling
cnn_model.add(Conv2D(16,
                     kernel_size=3,
                     activation='relu'))
cnn_model.add(MaxPooling2D(pool_size=(2,2)))
cnn_model.add(Flatten())
# Add a densely-connected layer with 128 neurons.
cnn_model.add(Dense(128, activation='relu'))
# Dropout layer
cnn_model.add(Dropout(0.5))
# Add a final layer with 2 neurons.
cnn_model.add(Dense(1, activation='sigmoid'))

# Early stopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)

# Compile model
cnn_model.compile(loss='binary_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])

# %%
cnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 398, 398, 6)       168
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 199, 199, 6)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 197, 197, 16)      880
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 98, 98, 16)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 153664)            0
# _________________________________________________________________
# dense (Dense)                (None, 128)               19669120
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 19,670,297
# Trainable params: 19,670,297
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fit model on training data
history = cnn_model.fit(X_train_ss,
                        y_train['label'],
                        batch_size=64,
                        validation_data=(X_test_ss, y_test['label']),
                        epochs=30,
                        callbacks=[es],
                        verbose=1)
# Out:
# Epoch 1/30
# 12/12 [==============================] - 65s 5s/step - loss: 8.0361 - accuracy: 0.4636 - val_loss: 1.3086 - val_accuracy: 0.5020
# Epoch 2/30
# 12/12 [==============================] - 48s 4s/step - loss: 1.1157 - accuracy: 0.5541 - val_loss: 0.6811 - val_accuracy: 0.5020
# Epoch 3/30
# 12/12 [==============================] - 50s 4s/step - loss: 0.6951 - accuracy: 0.5177 - val_loss: 0.6631 - val_accuracy: 0.5020
# Epoch 4/30
# 12/12 [==============================] - 50s 4s/step - loss: 0.6290 - accuracy: 0.6577 - val_loss: 0.6292 - val_accuracy: 0.6335
# Epoch 5/30
# 12/12 [==============================] - 51s 4s/step - loss: 0.5281 - accuracy: 0.7587 - val_loss: 0.5686 - val_accuracy: 0.6892
# Epoch 6/30
# 12/12 [==============================] - 50s 4s/step - loss: 0.3734 - accuracy: 0.8648 - val_loss: 0.5563 - val_accuracy: 0.6733
# Epoch 7/30
# 12/12 [==============================] - 50s 4s/step - loss: 0.2367 - accuracy: 0.9654 - val_loss: 0.4892 - val_accuracy: 0.7371
# Epoch 8/30
# 12/12 [==============================] - 50s 4s/step - loss: 0.1553 - accuracy: 0.9628 - val_loss: 0.5036 - val_accuracy: 0.7410
# Epoch 9/30
# 12/12 [==============================] - 50s 4s/step - loss: 0.0827 - accuracy: 0.9860 - val_loss: 0.5692 - val_accuracy: 0.7410
# Epoch 10/30
# 12/12 [==============================] - 50s 4s/step - loss: 0.0601 - accuracy: 0.9941 - val_loss: 0.6115 - val_accuracy: 0.7012
# Epoch 11/30
# 12/12 [==============================] - 51s 4s/step - loss: 0.0453 - accuracy: 0.9900 - val_loss: 0.5927 - val_accuracy: 0.7450
# Epoch 12/30
# 12/12 [==============================] - 50s 4s/step - loss: 0.0297 - accuracy: 0.9989 - val_loss: 0.6544 - val_accuracy: 0.7450
# Epoch 00012: early stopping

# %%
train_loss = history.history['loss']
test_loss = history.history['val_loss']
plt.figure(figsize=(12, 8))
plt.plot(train_loss, label='Training loss', color='navy')
plt.plot(test_loss, label='Testing loss', color='skyblue')
plt.legend();

# %% [markdown]
# #### List out the images of misclassification - test images

# %%
y_test.head(10)
# Out:
#      label                                         image_link   id
# 80     0.0    ../images/old_samples/photo-14708183-qHQJm9.jpg   80
# 191    0.0   ../images/old_interior/photo-14636851-wYM9I8.jpg  191
# 259    0.0  ../../capstone_more_images/old/photo-14695185-...  259
# 500    0.0  ../../capstone_more_images/old/photo-14660701-...  500
# 300    0.0  ../../capstone_more_images/old/photo-14684033-...  300
# 836    1.0  ../../capstone_more_images/modern/photo-146582...  836
# 576    1.0  ../images/modern_samples/photo-14629483-rr98Cc...  576
# 273    0.0  ../../capstone_more_images/old/photo-14649221-...  273
# 908    1.0  ../../capstone_more_images/modern/photo-146869...  908
# 404    0.0  ../../capstone_more_images/old/photo-14709642-...  404

# %%
y_pred = cnn_model.predict(X_test_ss)

# %%
y_pred.shape
# Out:
# (251, 1)

# %%
y_test['pred'] = y_pred.round()
y_test['prob'] = y_pred.round(3)
y_test.head(10)
# Out:
# c:\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# c:\python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      label                                         image_link   id  pred  \
# 80     0.0    ../images/old_samples/photo-14708183-qHQJm9.jpg   80   0.0
# 191    0.0   ../images/old_interior/photo-14636851-wYM9I8.jpg  191   0.0
# 259    0.0  ../../capstone_more_images/old/photo-14695185-...  259   1.0
# 500    0.0  ../../capstone_more_images/old/photo-14660701-...  500   1.0
# 300    0.0  ../../capstone_more_images/old/photo-14684033-...  300   0.0
# 836    1.0  ../../capstone_more_images/modern/photo-146582...  836   1.0
# 576    1.0  ../images/modern_samples/photo-14629483-rr98Cc...  576   1.0
# 273    0.0  ../../capstone_more_images/old/photo-14649221-...  273   0.0
# 908    1.0  ../../capstone_more_images/modern/photo-146869...  908   0.0
# 404    0.0  ../../capstone_more_images/old/photo-14709642-...  404   0.0
#
#       prob
# 80   0.039
# 191  0.331
# 259  0.757
# 500  0.802
# 300  0.049
# 836  1.000
# 576  0.894
# 273  0.001
# 908  0.402
# 404  0.175

# %%
# count the number of photos misclassified in y_test
y_test_misclassified = y_test[["image_link", "label", "pred", "prob"]][y_test["label"] != y_test["pred"]]

print(f"total number in y_test: {y_test.shape[0]}")
print(f"misclassified in y_test: {y_test_misclassified.shape[0]}")
y_test_misclassified.head()
# Out:
# total number in y_test: 251
# misclassified in y_test: 64
#                                             image_link  label  pred   prob
# 259  ../../capstone_more_images/old/photo-14695185-...    0.0   1.0  0.757
# 500  ../../capstone_more_images/old/photo-14660701-...    0.0   1.0  0.802
# 908  ../../capstone_more_images/modern/photo-146869...    1.0   0.0  0.402
# 757  ../../capstone_more_images/modern/photo-147001...    1.0   0.0  0.150
# 928  ../../capstone_more_images/modern/photo-147021...    1.0   0.0  0.031

# %%
# show the first 20 photos misclassified in y_test
display_no = min(20, y_test_misclassified.shape[0])

fig, ax = plt.subplots(ceil(display_no/2), 2, figsize=(8,32))
j=0
for i in y_test_misclassified.index[:display_no]:
    row = j//2
    col = j%2
    image_link = y_test_misclassified.loc[i, "image_link"]
    ax[row][col].imshow(io.imread(image_link))
    ax[row][col].set_title("label:" + str(y_test_misclassified.loc[i, "label"]) + ", pred:" + str(y_test_misclassified.loc[i, "pred"]) + "prob:"  + str(y_test_misclassified.loc[i, "prob"]))
    ax[row][col].axis('off')
    j += 1

print(j)
# Out:
# 20

# %% [markdown]
# ### Saving the model

# %%
model_tag = "model4a"

# %%
# Save the model
model = cnn_model

path = '../models/' + model_tag + '/'
model.save(path)
# Out:
# INFO:tensorflow:Assets written to: ../models/model3b/assets

# %%
# save the scaler
pickle.dump(ss, open('../models/' + model_tag + '/scaler.pkl', 'wb'))
